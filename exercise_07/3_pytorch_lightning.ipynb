# %% [markdown]
# # Pytorch Lightning Introduction
#
# Welcome to the introduction to [`PyTorchLightning`](https://www.pytorchlightning.ai/). PyTorch Lightning is a wrapper for PyTorch that is focused towards building neural networks model quickly by removing the boilerplate code. It also extends the functionality of PyTorch, for example, with model Callbacks and automatic porting to GPU to accelerate computations.
#
# In its essence, pytorch lightning provides a controlled setup where you are forced to in its specific partly automated library setup, but are able to customize/de-automatate each process if you so desire. You can both rely on a variety of already implemented functionalities and the fact that your code is by definition structured clearly, but at the cost of having to delve into their code structure and figuring out which functions to use.
#
# Our suggestion is to try it out. If you like it, cool, otherwise you can just stick to pytorch and build up your own library of functions you will use throughout your Deep Learning journey.
#
# Let's get started by installing PyTorch Lightning.

# %% [markdown]
# ## (Optional) Mount folder in Colab
#
# Uncomment thefollowing cell to mount your gdrive if you are using the notebook in google colab:

# %%
from google.colab import drive
import os

gdrive_path='/content/gdrive/MyDrive/I2DL/exercise_07'

# This will mount your google drive under 'MyDrive'
drive.mount('/content/gdrive', force_remount=True)
# In order to access the files in this notebook we have to navigate to the correct folder
os.chdir(gdrive_path)
# Check manually if all files are present
print(sorted(os.listdir()))
# Out:
# Mounted at /content/gdrive
# ['1_pytorch.ipynb', '2_tensorboard.ipynb', '3_pytorch_lightning.ipynb', '4_Cifar10_PytorchLightning.ipynb', '__init__.py', 'exercise_code', 'images', 'runs']

# %%
# Optional: install correct libraries in google colab
# !python -m pip install torch==1.11.0+cu113 torchvision==0.12.0+cu113 -f https://download.pytorch.org/whl/torch_stable.html
# !python -m pip install torchtext==0.12.0 torchaudio==0.11.0
# !python -m pip install tensorboard==2.9.1
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# Collecting torch==1.11.0+cu113
#   Downloading https://download.pytorch.org/whl/cu113/torch-1.11.0%2Bcu113-cp38-cp38-linux_x86_64.whl (1637.0 MB)
#      |████████████████▎               | 834.1 MB 1.4 MB/s eta 0:09:51tcmalloc: large alloc 1147494400 bytes == 0x39ad8000 @  0x7f4c4764d615 0x5d6f4c 0x51edd1 0x51ef5b 0x4f750a 0x4997a2 0x4fd8b5 0x4997c7 0x4fd8b5 0x49abe4 0x4f5fe9 0x55e146 0x4f5fe9 0x55e146 0x4f5fe9 0x55e146 0x5d8868 0x5da092 0x587116 0x5d8d8c 0x55dc1e 0x55cd91 0x5d8941 0x49abe4 0x55cd91 0x5d8941 0x4990ca 0x5d8868 0x4997a2 0x4fd8b5 0x49abe4
#      |████████████████████▋           | 1055.7 MB 1.3 MB/s eta 0:07:39tcmalloc: large alloc 1434370048 bytes == 0x7e12e000 @  0x7f4c4764d615 0x5d6f4c 0x51edd1 0x51ef5b 0x4f750a 0x4997a2 0x4fd8b5 0x4997c7 0x4fd8b5 0x49abe4 0x4f5fe9 0x55e146 0x4f5fe9 0x55e146 0x4f5fe9 0x55e146 0x5d8868 0x5da092 0x587116 0x5d8d8c 0x55dc1e 0x55cd91 0x5d8941 0x49abe4 0x55cd91 0x5d8941 0x4990ca 0x5d8868 0x4997a2 0x4fd8b5 0x49abe4
#      |██████████████████████████▏     | 1336.2 MB 1.2 MB/s eta 0:04:11tcmalloc: large alloc 1792966656 bytes == 0x2f60000 @  0x7f4c4764d615 0x5d6f4c 0x51edd1 0x51ef5b 0x4f750a 0x4997a2 0x4fd8b5 0x4997c7 0x4fd8b5 0x49abe4 0x4f5fe9 0x55e146 0x4f5fe9 0x55e146 0x4f5fe9 0x55e146 0x5d8868 0x5da092 0x587116 0x5d8d8c 0x55dc1e 0x55cd91 0x5d8941 0x49abe4 0x55cd91 0x5d8941 0x4990ca 0x5d8868 0x4997a2 0x4fd8b5 0x49abe4
#      |████████████████████████████████| 1637.0 MB 1.2 MB/s eta 0:00:01tcmalloc: large alloc 1636999168 bytes == 0x6dd48000 @  0x7f4c4764c1e7 0x4d30a0 0x4d312c 0x5d6f4c 0x51edd1 0x51ef5b 0x4f750a 0x4997a2 0x55cd91 0x5d8941 0x4997a2 0x55cd91 0x5d8941 0x4997a2 0x55cd91 0x5d8941 0x4997a2 0x55cd91 0x5d8941 0x4997a2 0x55cd91 0x5d8941 0x4997a2 0x5d8868 0x4997a2 0x55cd91 0x5d8941 0x49abe4 0x4fd8b5 0x49abe4 0x55cd91
# tcmalloc: large alloc 2046255104 bytes == 0xcf672000 @  0x7f4c4764d615 0x5d6f4c 0x51edd1 0x51ef5b 0x4f750a 0x4997a2 0x55cd91 0x5d8941 0x4997a2 0x55cd91 0x5d8941 0x4997a2 0x55cd91 0x5d8941 0x4997a2 0x55cd91 0x5d8941 0x4997a2 0x55cd91 0x5d8941 0x4997a2 0x5d8868 0x4997a2 0x55cd91 0x5d8941 0x49abe4 0x4fd8b5 0x49abe4 0x55cd91 0x5d8941 0x4fe318
#      |████████████████████████████████| 1637.0 MB 10.0 kB/s
# Collecting torchvision==0.12.0+cu113
#   Downloading https://download.pytorch.org/whl/cu113/torchvision-0.12.0%2Bcu113-cp38-cp38-linux_x86_64.whl (22.3 MB)
#      |████████████████████████████████| 22.3 MB 1.3 MB/s
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from torch==1.11.0+cu113) (4.4.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.8/dist-packages (from torchvision==0.12.0+cu113) (7.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from torchvision==0.12.0+cu113) (1.21.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from torchvision==0.12.0+cu113) (2.23.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->torchvision==0.12.0+cu113) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->torchvision==0.12.0+cu113) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->torchvision==0.12.0+cu113) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->torchvision==0.12.0+cu113) (2022.9.24)
# Installing collected packages: torch, torchvision
#   Attempting uninstall: torch
#     Found existing installation: torch 1.13.0+cu116
#     Uninstalling torch-1.13.0+cu116:
#       Successfully uninstalled torch-1.13.0+cu116
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.14.0+cu116
#     Uninstalling torchvision-0.14.0+cu116:
#       Successfully uninstalled torchvision-0.14.0+cu116
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchtext 0.14.0 requires torch==1.13.0, but you have torch 1.11.0+cu113 which is incompatible.
# torchaudio 0.13.0+cu116 requires torch==1.13.0, but you have torch 1.11.0+cu113 which is incompatible.
# Successfully installed torch-1.11.0+cu113 torchvision-0.12.0+cu113
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting torchtext==0.12.0
#   Downloading torchtext-0.12.0-cp38-cp38-manylinux1_x86_64.whl (10.4 MB)
#      |████████████████████████████████| 10.4 MB 9.1 MB/s
# Collecting torchaudio==0.11.0
#   Downloading torchaudio-0.11.0-cp38-cp38-manylinux1_x86_64.whl (2.9 MB)
#      |████████████████████████████████| 2.9 MB 48.8 MB/s
# Requirement already satisfied: torch==1.11.0 in /usr/local/lib/python3.8/dist-packages (from torchtext==0.12.0) (1.11.0+cu113)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from torchtext==0.12.0) (4.64.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from torchtext==0.12.0) (2.23.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from torchtext==0.12.0) (1.21.6)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from torch==1.11.0->torchtext==0.12.0) (4.4.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->torchtext==0.12.0) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->torchtext==0.12.0) (2022.9.24)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->torchtext==0.12.0) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->torchtext==0.12.0) (2.10)
# Installing collected packages: torchtext, torchaudio
#   Attempting uninstall: torchtext
#     Found existing installation: torchtext 0.14.0
#     Uninstalling torchtext-0.14.0:
#       Successfully uninstalled torchtext-0.14.0
#   Attempting uninstall: torchaudio
#     Found existing installation: torchaudio 0.13.0+cu116
#     Uninstalling torchaudio-0.13.0+cu116:
#       Successfully uninstalled torchaudio-0.13.0+cu116
# Successfully installed torchaudio-0.11.0 torchtext-0.12.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tensorboard==2.9.1 in /usr/local/lib/python3.8/dist-packages (2.9.1)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard==2.9.1) (57.4.0)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard==2.9.1) (1.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.8/dist-packages (from tensorboard==2.9.1) (3.4.1)
# Requirement already satisfied: numpy>=1.12.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard==2.9.1) (1.21.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard==2.9.1) (0.6.1)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.8/dist-packages (from tensorboard==2.9.1) (1.51.1)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.8/dist-packages (from tensorboard==2.9.1) (0.38.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard==2.9.1) (2.23.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.8/dist-packages (from tensorboard==2.9.1) (1.3.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard==2.9.1) (1.8.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.8/dist-packages (from tensorboard==2.9.1) (2.15.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /usr/local/lib/python3.8/dist-packages (from tensorboard==2.9.1) (3.19.6)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard==2.9.1) (0.4.6)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard==2.9.1) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard==2.9.1) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard==2.9.1) (5.2.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard==2.9.1) (1.15.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.8/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard==2.9.1) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.8/dist-packages (from markdown>=2.6.8->tensorboard==2.9.1) (4.13.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard==2.9.1) (3.11.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.8/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard==2.9.1) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard==2.9.1) (2022.9.24)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard==2.9.1) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard==2.9.1) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard==2.9.1) (2.10)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.8/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard==2.9.1) (3.2.2)

# %% [markdown]
# ### Installing Pytorch Lightning

# %%
# For automatic file reloading as usual
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import sys

# For google colab
# !python -m pip install pytorch-lightning==1.6.0 > /dev/null

# For anaconda/regular python
# !{sys.executable} -m pip install pytorch-lightning==1.6.0

# %%
import pytorch_lightning as pl
print(f"Lightning version: {pl.__version__}")
if not pl.__version__.startswith("1.6"):
    print("You are using another version of pytorch lightning. We expect pytorch lightning 1.6.0. You can continue with your version but it"
          " might cause dependency and compatibility issues.")

import tensorboard
import torch
import torchvision
print(f"Tensorboard version: {tensorboard.__version__}")
if not tensorboard.__version__.startswith("2.9.1"):
    print("You are using an another version of Tensorboard. We expect Tensorboard 2.9.1 You may continue using your version but it"
          " might cause dependency and compatibility issues.")
print(f"PyTorch version Installed: {torch.__version__}\nTorchvision version Installed: {torchvision.__version__}\n")
if not torch.__version__.startswith("1.11"):
    print("you are using an another version of PyTorch. We expect PyTorch 1.11.0. You may continue using your version but it"
          " might cause dependency and compatibility issues.")
if not torchvision.__version__.startswith("0.12"):
    print("you are using an another version of torchvision. We expect torchvision 0.12. You can continue with your version but it"
          " might cause dependency and compatibility issues.")
# Out:
# Lightning version: 1.6.0
# Tensorboard version: 2.9.1
# PyTorch version Installed: 1.11.0+cu113
# Torchvision version Installed: 0.12.0+cu113

# %% [markdown]
# # 1. Idea behind PyTorch Lightning
#
# Codes in a Deep learning project consists of three main categories:
#
# 1. **Research code**
#     This is the exciting part of the experiment where you configure the model architecture and try out different optimizers and target task. This is managed by the `LightningModule` of PyTorch Lightning.
#
# 2. **Engineering code**
#     This is the same set of code that remain the same for all deep learning projects.Recall the training block of previous notebooks where we loop through the epochs and mini-batches. The `Trainer` class of PyTorch Lightning takes care of this part of code.
#
# 3. **Non-essential code**
#     It is very important that we log our training metrics and organize different training runs to have purposeful experimentation of models. The `Callbacks` class PyTorch Lightning helps us with this section.
#
# Let's look at each of these modules in detail.
#
# 1. **LightningModules** contain all model related code. This is the part where we are working on when creating a new project. The idea is to have all important code in one module, e.g., the model's architecture and the evaluation of training and validation metrics. This provides a better overview as repeated elements, such as the training procedure, are not stored in the code that we work on. The lightning module also handles the calls `.to(device)` or `.train()` and `.eval()`. Hence, there is no need anymore to switch between the cpu and gpu and to take care of the model's mode as this is automated by the LightningModule. The framework also enables easy parallel computation on multiple gpus.
#
# 2. **Trainer** contains all code needed for training our neural networks that doesn't change for each project ("one size fits all"). Usually, we don't touch the code automated by this class. The arguments that are specific for one training such as learning rate and batch size are provided as initialization arguments for the LightningModule.
#
# 3. **Callbacks** automate all parts needed for logging hyperparameters or training results such as the tensorboard logger. Logging becomes very important for research later since the results of experiments need to be reproducible.
#
# All in all, PyTorch is a framework that handles all (annoying) "engineering" stuff for you such that you have more time for exciting research and scientific coding. This also results in the advantage that automated parts are guaranteed to be bug-free. Hence, you can't include a bug in a part of your code that is often used but not often checked.

# %% [markdown]
# # 2. Overview of the PyTorch Lightning code

# %% [markdown]
# Research relevant code goes into the `LightningModule`. The advantage is that we have all the model building, training & validation steps within a single class. These are the components that usually change based on the projects and tasks.

# %% [markdown]
# ![tensorBoard Interface](./images/pl_quick_start_full_compressed.gif)

# %% [markdown]
# The remaining code is automated by the `Trainer` class which takes care of the tasks of our mechanical training loops components such as iterating through the minibatches and gradient updating steps.

# %% [markdown]
# ![alt text](https://miro.medium.com/max/700/1*b81_j__xv8M0Bb6nFTXbAA.png)

# %% [markdown]
# We could already see how much more readable and concise our code is, after being transformed by PyTorch Lightning.
#
# Let us now train a neural network model with PyTorch Lightning.

# %% [markdown]
# # 3. Training with PyTorch Lightning
#
# We will build a two-layer neural network to train on the the [`Fashion-MNIST`](https://research.zalando.com/welcome/mission/research-projects/fashion-mnist/) dataset for this notebook.
#
# ## 3.1 Define A LightningModule
#
# We define our network as an instance of `pl.LightningModule` which replaces our `PyTorch` network based on the class `nn.Module`. Additionally, it contains all the relevant parts that are used for training and evaluating different models on various tasks.
#
# Let's have a look at the implementation of `TwoLayerNet` in `exercise_code.lightning_models`.

# %% [markdown]
# The `__init__()` and `forward()` function defining the forward  pass remain the same. Hence, we can just copy the code from the `nn.Module`.

# %% [markdown]
# ```python
# class TwoLayerNet(pl.LightningModule):
#     def __init__(self, hparams, input_size=1 * 28 * 28, hidden_size=512, num_classes=10):
#         super().__init__()
#         self.save_hyperparameters(hparams)
#
#         self.model = nn.Sequential(
#             nn.Linear(input_size, hidden_size),
#             nn.Sigmoid(),
#             nn.Linear(hidden_size, num_classes),
#         )
#
#     def forward(self, x):
#         # flatten the image  before sending as input to the model
#         N, _, _, _ = x.shape
#         x = x.view(N, -1)
#
#         x = self.model(x)
#
#         return x
# ```

# %% [markdown]
# We will now define the training  and validation steps since they also vary with different tasks and projects. Consequently, it is useful to integrate these parts into our instance of `LightningModule`. Validation loss is returned for each validation mini-batch and averaged at the end of the epoch.

# %% [markdown]
# ```python
#     def training_step(self, batch, batch_idx):
#         images, targets = batch
#
#         # Perform a forward pass on the network with inputs
#         out = self.forward(images)
#
#         # calculate the loss with the network predictions and ground truth targets
#         loss = F.cross_entropy(out, targets)
#
#         # Find the predicted class from probabilities of the image belonging to each of the classes
#         # from the network output
#         _, preds = torch.max(out, 1)
#
#         # Calculate the accuracy of predictions
#         acc = preds.eq(targets).sum().float() / targets.size(0)
#
#         # Log the accuracy and loss values to the tensorboard
#         self.log('loss', loss)
#         self.log('acc', acc)
#
#         return {'loss': loss}
#
#     def validation_step(self, batch, batch_idx):
#         images, targets = batch
#
#         # Perform a forward pass on the network with inputs
#         out = self.forward(images)
#
#         # calculate the loss with the network predictions and ground truth targets
#         loss = F.cross_entropy(out, targets)
#
#         # Find the predicted class from probabilities of the image belonging to each of the classes
#         # from the network output
#         _, preds = torch.max(out, 1)
#
#         # Calculate the accuracy of predictions
#         acc = preds.eq(targets).sum().float() / targets.size(0)
#
#         # Visualise the predictions  of the model
#         if batch_idx == 0:
#             self.visualize_predictions(images, out.detach(), targets)
#
#         return {'val_loss': loss, 'val_acc': acc}
#
#     def validation_epoch_end(self, outputs):
#
#         # Average the loss over the entire validation data from it's mini-batches
#         avg_loss = torch.stack([x['val_loss'] for x in outputs]).mean()
#         avg_acc = torch.stack([x['val_acc'] for x in outputs]).mean()
#
#         # Log the validation accuracy and loss values to the tensorboard
#         self.log('val_loss', avg_loss)
#         self.log('val_acc', avg_acc)
# ```

# %% [markdown]
# The last step missing in our `LightningModule` is the optimizer. This method needs to be defined in every `LightningModule`.

# %% [markdown]
# ```python
#     def configure_optimizers(self):
#         optim = torch.optim.SGD(self.model.parameters(), self.hparams["learning_rate"], momentum=0.9)
#
#         return optim
# ```

# %% [markdown]
# Now that we have set up the model and the training steps, we will now establish the data pipeline. PyTorch Lightning provides the `LightningDataModule` for setting up the dataloaders.
#
# Let's have a look at the implementation of `FashionMNISTDataModule` in `exercise_code.data_class`.
#
# The `prepare_data()` function intends to set up the dataset and the related transforms for it. As previously, we download the `FashionMNIST` dataset using `torchvision` and split the total training data into a training and validation set for tuning hyperparameters.

# %% [markdown]
# ```python
# class FashionMNISTDataModule(pl.LightningDataModule):
#
#     def __init__(self, batch_size=4):
#         super().__init__()
#         self.batch_size = batch_size
#
#     def prepare_data(self):
#
#         # Define the transform
#         transform = transforms.Compose([transforms.ToTensor(),
#                                         transforms.Normalize((0.5,), (0.5,))])
#
#         # Download the Fashion-MNIST dataset
#         fashion_mnist_train_val = torchvision.datasets.FashionMNIST(root='../datasets', train=True,
#                                                                    download=True, transform=transform)
#
#         self.fashion_mnist_test = torchvision.datasets.FashionMNIST(root='../datasets', train=False,
#                                                                  download=True, transform=transform)
#
#         # Apply the Transforms
#         transform = transforms.Compose([transforms.ToTensor(),
#                                         transforms.Normalize((0.5,), (0.5,))])
#
#         # Perform the training and validation split
#         self.train_dataset, self.val_dataset = random_split(
#             fashion_mnist_train_val, [50000, 10000])
# ```

# %% [markdown]
# We shall now define `Dataloaders` for each of the data-splits. These data loaders can be directly called during model training!

# %% [markdown]
# ```python
#
#     def train_dataloader(self):
#         return DataLoader(self.train_dataset, batch_size=self.batch_size)
#
#     def val_dataloader(self):
#         return DataLoader(self.val_dataset, batch_size=self.batch_size)
#
#     def test_dataloader(self):
#         return DataLoader(self.fashion_mnist_test, batch_size=self.batch_size)
#
# ```

# %% [markdown]
# You can notice now that most of the code of these steps can be directly copied from a Vanilla PyTorch code. Lightning just rearranges them. This marks the end of the research part of the code.
#
# Let's see now how the `Trainer` class works:

# %% [markdown]
# ##  3.2 Fitting the model with a Trainer

# %% [markdown]
# We will initialize the model and the data  with a set of hyperparameters given in the dictionary `hparams`.

# %%
from IPython.display import clear_output 

from exercise_code.lightning_models import TwoLayerNet
from exercise_code.data_class import FashionMNISTDataModule

hparams = {
    "batch_size": 16,
    "learning_rate": 1e-3,
    "input_size": 1 * 28 * 28,
    "hidden_size": 512,
    "num_classes": 10,
    "num_workers": 2,    # used by the dataloader, more workers means faster data preparation, but for us this is not a bottleneck here
}


model = TwoLayerNet(hparams)
data=FashionMNISTDataModule(hparams)
data.prepare_data()

# %% [markdown]
#  PyTorch Lightning provides ample flexibility for training using [`Trainer`](https://pytorch-lightning.readthedocs.io/en/latest/trainer.html) class.
# Have a look at the documentation to know more about them!
#
# Let's initialize it now!

# %%
trainer = pl.Trainer(
    max_epochs=2,
    accelerator="auto"
)
# Out:
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: False, used: False
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs

# %% [markdown]
# The argument `max_epochs` sets the maximum number of epochs for training.
# The argument `weights_summary` prints a summary of the number of weights per layer at the beginning of the training. Set it to None if the summary is not required.

# %% [markdown]
# Here comes the actual training cell. The [`fit`](https://pytorch-lightning.readthedocs.io/en/latest/_modules/pytorch_lightning/trainer/trainer.html#Trainer.fit) function takes in the model and data to train the model with a lot more optional arguments for customization.

# %%
trainer.fit(model, data)
# Out:
# WARNING:pytorch_lightning.loggers.tensorboard:Missing logger folder: /content/gdrive/MyDrive/I2DL/exercise_07/lightning_logs
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name  | Type       | Params
# -------------------------------------
# 0 | model | Sequential | 407 K
# -------------------------------------
# 407 K     Trainable params
# 0         Non-trainable params
# 407 K     Total params
# 1.628     Total estimated model params size (MB)
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]

# %% [markdown]
# Checkout the directory `lightning_logs`. For each run there is a new directory `version_xx` created. The rightmost argument in the progress bar, the `v_num` variable above shows the version of the current run. Each directory automatically contains a folder with checkpoints, logs and the hyperparameters for this run.
#
# As seen in the last notebook, you can have a look at the  logs of the runs in the TensorBoard
# Use the command as in the previous notebook in your terminal
# ```
# tensorboard --logdir lightning_logs
# ```
# Make sure to use the above command as the same directory as `exercise_07`.

# %% [markdown]
# If you are using Google Colab, run the following cell to load the TensorBoard extension within the notebook. You may have to scroll to this block whenever you need to look at the TensorBoard interface.

# %%
# %load_ext tensorboard
# %tensorboard --logdir lightning_logs
# Out:
# UsageError: Line magic function `%tensorboard` not found.

# %% [markdown]
# ## 3.3 Add images to tensorboard

# %% [markdown]
# The tensorboard logger is a submodule of the `LightningModule` and can be accessed via `self.logger`. We can  add images  to the logging module by calling
# ```python
# self.logger.experiment.add_image('tag', image)
# ```
# to add an image.
#
#
# We will log the first batch of validation images in a grid together with the predicted class labels and the ground truth labels.
#
# ```python
#         if batch_idx == 0:
#             self.visualize_predictions(images, out.detach(), targets)
# ```
#
# Let's have a look at the implementation of `visualize_predictions()` function in `exercise_code.lightning_models`.
#
#
#
# ```python
#     def visualize_predictions(self, images, preds, targets):
#         class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
#                        'dog', 'frog', 'horse', 'ship', 'truck']
#
#         # determine size of the grid based on given batch size
#         num_rows = torch.tensor(len(images)).float().sqrt().floor()
#
#         fig = plt.figure(figsize=(10, 10))
#         for i in range(len(images)):
#             plt.subplot(num_rows ,len(images) // num_rows + 1, i+1)
#             plt.imshow(images[i].permute(1, 2, 0))
#             plt.title(class_names[torch.argmax(preds, axis=-1)[i]] + f'\n[{class_names[targets[i]]}]')
#             plt.axis('off')
#
#         self.logger.experiment.add_figure('predictions', fig, global_step=self.global_step)
# ```
#
# You can view the logged images in your `IMAGES` tab of TensorBoard.

# %% [markdown]
# We have now looked at how to train a model using PyTorch Lightning. PyTorch Lightning is very active in developement and the features set are continously expanded and updated.

# %% [markdown]
# # 3. Other Features of PyTorch Lightning
#
#
# ### Checking  training timings
#
# The argument `profiler` of the `Trainer` class measures the time taken in different steps such as dataloading, forward and backward pass. You can select a variety of loggers [here](https://pytorch-lightning.readthedocs.io/en/stable/advanced/profiler.html).
#
# Run the cell below to see for yourself.

# %%
trainer = pl.Trainer(
    profiler='simple',
    max_epochs=1,
    accelerator="auto"
)

trainer.fit(model, data)
# Out:
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: False, used: False
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name  | Type       | Params
# -------------------------------------
# 0 | model | Sequential | 407 K
# -------------------------------------
# 407 K     Trainable params
# 0         Non-trainable params
# 407 K     Total params
# 1.628     Total estimated model params size (MB)
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.profiler.profiler:FIT Profiler Report
#
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |  Action                                                                                                                                                                                                    	|  Mean duration (s)	|  Num calls      	|  Total time (s) 	|  Percentage %   	|
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |  Total                                                                                                                                                                                                     	|  -              	|  137063         	|  68.143         	|  100 %          	|
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |  run_training_epoch                                                                                                                                                                                        	|  67.18          	|  1              	|  67.18          	|  98.587         	|
# |  run_training_batch                                                                                                                                                                                        	|  0.0075439      	|  3125           	|  23.575         	|  34.596         	|
# |  [LightningModule]TwoLayerNet.optimizer_step                                                                                                                                                               	|  0.0070072      	|  3125           	|  21.897         	|  32.135         	|
# |  on_train_batch_end                                                                                                                                                                                        	|  0.0046487      	|  3125           	|  14.527         	|  21.319         	|
# |  [Strategy]SingleDeviceStrategy.training_step                                                                                                                                                              	|  0.0022799      	|  3125           	|  7.1246         	|  10.455         	|
# |  [Strategy]SingleDeviceStrategy.backward                                                                                                                                                                   	|  0.0020998      	|  3125           	|  6.5618         	|  9.6295         	|
# |  [Callback]TQDMProgressBar.on_validation_batch_end                                                                                                                                                         	|  0.0044274      	|  627            	|  2.776          	|  4.0738         	|
# |  [Strategy]SingleDeviceStrategy.validation_step                                                                                                                                                            	|  0.0033809      	|  627            	|  2.1198         	|  3.1108         	|
# |  [LightningModule]TwoLayerNet.optimizer_zero_grad                                                                                                                                                          	|  0.00045382     	|  3125           	|  1.4182         	|  2.0812         	|
# |  on_train_batch_start                                                                                                                                                                                      	|  0.00024894     	|  3125           	|  0.77795        	|  1.1416         	|
# |  [Strategy]SingleDeviceStrategy.batch_to_device                                                                                                                                                            	|  0.00014701     	|  3752           	|  0.55159        	|  0.80947        	|
# |  [Callback]TQDMProgressBar.on_train_start                                                                                                                                                                  	|  0.064624       	|  1              	|  0.064624       	|  0.094837       	|
# |  [Callback]TQDMProgressBar.on_validation_start                                                                                                                                                             	|  0.024548       	|  2              	|  0.049096       	|  0.072049       	|
# |  [Callback]ModelSummary.on_validation_batch_end                                                                                                                                                            	|  7.5997e-05     	|  627            	|  0.04765        	|  0.069926       	|
# |  [Callback]TQDMProgressBar.on_sanity_check_start                                                                                                                                                           	|  0.044356       	|  1              	|  0.044356       	|  0.065092       	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_train_epoch_end                 	|  0.039465       	|  1              	|  0.039465       	|  0.057915       	|
# |  [Callback]TQDMProgressBar.on_validation_batch_start                                                                                                                                                       	|  5.5559e-05     	|  627            	|  0.034835       	|  0.051121       	|
# |  [Callback]TQDMProgressBar.on_after_backward                                                                                                                                                               	|  9.9372e-06     	|  3125           	|  0.031054       	|  0.045571       	|
# |  [Callback]TQDMProgressBar.on_before_zero_grad                                                                                                                                                             	|  9.0948e-06     	|  3125           	|  0.028421       	|  0.041709       	|
# |  [Callback]TQDMProgressBar.on_batch_end                                                                                                                                                                    	|  8.1548e-06     	|  3125           	|  0.025484       	|  0.037398       	|
# |  [Callback]TQDMProgressBar.on_before_backward                                                                                                                                                              	|  7.4379e-06     	|  3125           	|  0.023244       	|  0.03411        	|
# |  [Callback]TQDMProgressBar.on_batch_start                                                                                                                                                                  	|  7.089e-06      	|  3125           	|  0.022153       	|  0.03251        	|
# |  [Callback]TQDMProgressBar.on_before_optimizer_step                                                                                                                                                        	|  6.9196e-06     	|  3125           	|  0.021624       	|  0.031733       	|
# |  [Callback]ModelSummary.on_after_backward                                                                                                                                                                  	|  6.1689e-06     	|  3125           	|  0.019278       	|  0.02829        	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_batch_end                       	|  6.1006e-06     	|  3125           	|  0.019064       	|  0.027977       	|
# |  [Callback]ModelSummary.on_before_zero_grad                                                                                                                                                                	|  5.6942e-06     	|  3125           	|  0.017794       	|  0.026114       	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_before_zero_grad                	|  5.5515e-06     	|  3125           	|  0.017348       	|  0.025459       	|
# |  [Callback]ModelSummary.on_before_optimizer_step                                                                                                                                                           	|  5.5433e-06     	|  3125           	|  0.017323       	|  0.025422       	|
# |  [Callback]GradientAccumulationScheduler.on_before_zero_grad                                                                                                                                               	|  5.5215e-06     	|  3125           	|  0.017255       	|  0.025322       	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_before_optimizer_step           	|  5.434e-06      	|  3125           	|  0.016981       	|  0.02492        	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_before_backward                 	|  5.2069e-06     	|  3125           	|  0.016272       	|  0.023879       	|
# |  [Callback]ModelSummary.on_before_backward                                                                                                                                                                 	|  5.1438e-06     	|  3125           	|  0.016074       	|  0.023589       	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_after_backward                  	|  5.1215e-06     	|  3125           	|  0.016005       	|  0.023487       	|
# |  [Callback]GradientAccumulationScheduler.on_after_backward                                                                                                                                                 	|  5.1115e-06     	|  3125           	|  0.015974       	|  0.023441       	|
# |  [Callback]ModelSummary.on_batch_start                                                                                                                                                                     	|  5.0606e-06     	|  3125           	|  0.015814       	|  0.023208       	|
# |  [Callback]ModelSummary.on_batch_end                                                                                                                                                                       	|  5.0339e-06     	|  3125           	|  0.015731       	|  0.023085       	|
# |  [Callback]GradientAccumulationScheduler.on_before_optimizer_step                                                                                                                                          	|  4.8386e-06     	|  3125           	|  0.015121       	|  0.022189       	|
# |  [Callback]GradientAccumulationScheduler.on_batch_end                                                                                                                                                      	|  4.7869e-06     	|  3125           	|  0.014959       	|  0.021952       	|
# |  [Callback]GradientAccumulationScheduler.on_before_backward                                                                                                                                                	|  4.6561e-06     	|  3125           	|  0.01455        	|  0.021353       	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_batch_start                     	|  4.592e-06      	|  3125           	|  0.01435        	|  0.021059       	|
# |  [Callback]GradientAccumulationScheduler.on_batch_start                                                                                                                                                    	|  4.3406e-06     	|  3125           	|  0.013564       	|  0.019906       	|
# |  [LightningModule]TwoLayerNet.training_step_end                                                                                                                                                            	|  4.3247e-06     	|  3125           	|  0.013515       	|  0.019833       	|
# |  [LightningModule]TwoLayerNet.on_train_batch_end                                                                                                                                                           	|  3.9341e-06     	|  3125           	|  0.012294       	|  0.018042       	|
# |  [LightningModule]TwoLayerNet.on_after_backward                                                                                                                                                            	|  3.3843e-06     	|  3125           	|  0.010576       	|  0.01552        	|
# |  [LightningModule]TwoLayerNet.on_before_zero_grad                                                                                                                                                          	|  3.2094e-06     	|  3125           	|  0.010029       	|  0.014718       	|
# |  [Strategy]SingleDeviceStrategy.training_step_end                                                                                                                                                          	|  3.1469e-06     	|  3125           	|  0.009834       	|  0.014431       	|
# |  [LightningModule]TwoLayerNet.validation_epoch_end                                                                                                                                                         	|  0.0046853      	|  2              	|  0.0093705      	|  0.013751       	|
# |  [LightningModule]TwoLayerNet.on_before_backward                                                                                                                                                           	|  2.939e-06      	|  3125           	|  0.0091844      	|  0.013478       	|
# |  [LightningModule]TwoLayerNet.on_train_batch_start                                                                                                                                                         	|  2.8958e-06     	|  3125           	|  0.0090493      	|  0.01328        	|
# |  [Strategy]SingleDeviceStrategy.on_train_batch_start                                                                                                                                                       	|  2.7682e-06     	|  3125           	|  0.0086506      	|  0.012695       	|
# |  [Callback]TQDMProgressBar.on_validation_end                                                                                                                                                               	|  0.004036       	|  2              	|  0.0080719      	|  0.011846       	|
# |  [LightningModule]TwoLayerNet.on_before_optimizer_step                                                                                                                                                     	|  2.3171e-06     	|  3125           	|  0.007241       	|  0.010626       	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_validation_batch_end            	|  7.5362e-06     	|  627            	|  0.0047252      	|  0.0069342      	|
# |  [Callback]ModelSummary.on_validation_batch_start                                                                                                                                                          	|  6.9406e-06     	|  627            	|  0.0043518      	|  0.0063862      	|
# |  [Callback]GradientAccumulationScheduler.on_validation_batch_end                                                                                                                                           	|  5.8897e-06     	|  627            	|  0.0036929      	|  0.0054193      	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_validation_batch_start          	|  5.1575e-06     	|  627            	|  0.0032337      	|  0.0047455      	|
# |  [Callback]TQDMProgressBar.on_train_epoch_start                                                                                                                                                            	|  0.0031596      	|  1              	|  0.0031596      	|  0.0046367      	|
# |  [Callback]GradientAccumulationScheduler.on_validation_batch_start                                                                                                                                         	|  4.7594e-06     	|  627            	|  0.0029841      	|  0.0043793      	|
# |  [Callback]ModelSummary.on_fit_start                                                                                                                                                                       	|  0.0028673      	|  1              	|  0.0028673      	|  0.0042077      	|
# |  [LightningModule]TwoLayerNet.validation_step_end                                                                                                                                                          	|  4.0065e-06     	|  627            	|  0.0025121      	|  0.0036865      	|
# |  [LightningModule]TwoLayerNet.on_validation_batch_end                                                                                                                                                      	|  3.4947e-06     	|  627            	|  0.0021912      	|  0.0032156      	|
# |  [Strategy]SingleDeviceStrategy.validation_step_end                                                                                                                                                        	|  2.8198e-06     	|  627            	|  0.001768       	|  0.0025946      	|
# |  [LightningModule]TwoLayerNet.on_validation_batch_start                                                                                                                                                    	|  2.787e-06      	|  627            	|  0.0017474      	|  0.0025643      	|
# |  [Callback]TQDMProgressBar.on_train_end                                                                                                                                                                    	|  0.0014451      	|  1              	|  0.0014451      	|  0.0021206      	|
# |  [Callback]TQDMProgressBar.on_train_epoch_end                                                                                                                                                              	|  0.001099       	|  1              	|  0.001099       	|  0.0016128      	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': None}.setup                              	|  0.0004794      	|  1              	|  0.0004794      	|  0.00070352     	|
# |  [LightningModule]TwoLayerNet.on_validation_model_train                                                                                                                                                    	|  0.00015049     	|  2              	|  0.00030099     	|  0.0004417      	|
# |  [LightningModule]TwoLayerNet.on_validation_model_eval                                                                                                                                                     	|  0.00010306     	|  2              	|  0.00020611     	|  0.00030247     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_validation_end                  	|  6.6879e-05     	|  2              	|  0.00013376     	|  0.00019629     	|
# |  [LightningModule]TwoLayerNet.configure_optimizers                                                                                                                                                         	|  0.00011338     	|  1              	|  0.00011338     	|  0.00016639     	|
# |  [Callback]ModelSummary.on_validation_end                                                                                                                                                                  	|  3.1439e-05     	|  2              	|  6.2878e-05     	|  9.2274e-05     	|
# |  [Callback]ModelSummary.on_validation_start                                                                                                                                                                	|  2.7577e-05     	|  2              	|  5.5153e-05     	|  8.0937e-05     	|
# |  [Callback]ModelSummary.on_sanity_check_start                                                                                                                                                              	|  3.7372e-05     	|  1              	|  3.7372e-05     	|  5.4844e-05     	|
# |  [Callback]ModelSummary.on_train_start                                                                                                                                                                     	|  3.6879e-05     	|  1              	|  3.6879e-05     	|  5.412e-05      	|
# |  [Callback]GradientAccumulationScheduler.on_train_epoch_start                                                                                                                                              	|  3.43e-05       	|  1              	|  3.43e-05       	|  5.0336e-05     	|
# |  [Callback]TQDMProgressBar.on_validation_epoch_end                                                                                                                                                         	|  1.45e-05       	|  2              	|  2.9001e-05     	|  4.2559e-05     	|
# |  [Callback]ModelSummary.on_epoch_start                                                                                                                                                                     	|  9.355e-06      	|  3              	|  2.8065e-05     	|  4.1186e-05     	|
# |  [Callback]ModelSummary.on_train_epoch_start                                                                                                                                                               	|  2.6271e-05     	|  1              	|  2.6271e-05     	|  3.8553e-05     	|
# |  [Callback]GradientAccumulationScheduler.on_fit_start                                                                                                                                                      	|  2.1421e-05     	|  1              	|  2.1421e-05     	|  3.1435e-05     	|
# |  [LightningModule]TwoLayerNet.on_validation_epoch_end                                                                                                                                                      	|  1.0303e-05     	|  2              	|  2.0605e-05     	|  3.0238e-05     	|
# |  [Callback]TQDMProgressBar.on_save_checkpoint                                                                                                                                                              	|  1.9684e-05     	|  1              	|  1.9684e-05     	|  2.8886e-05     	|
# |  [Callback]TQDMProgressBar.on_sanity_check_end                                                                                                                                                             	|  1.8267e-05     	|  1              	|  1.8267e-05     	|  2.6807e-05     	|
# |  [Callback]TQDMProgressBar.on_epoch_start                                                                                                                                                                  	|  5.9683e-06     	|  3              	|  1.7905e-05     	|  2.6276e-05     	|
# |  [Callback]TQDMProgressBar.setup                                                                                                                                                                           	|  1.6009e-05     	|  1              	|  1.6009e-05     	|  2.3493e-05     	|
# |  [Callback]TQDMProgressBar.on_configure_sharded_model                                                                                                                                                      	|  1.4842e-05     	|  1              	|  1.4842e-05     	|  2.1781e-05     	|
# |  [Callback]TQDMProgressBar.on_epoch_end                                                                                                                                                                    	|  4.6503e-06     	|  3              	|  1.3951e-05     	|  2.0473e-05     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_epoch_start                     	|  4.2997e-06     	|  3              	|  1.2899e-05     	|  1.8929e-05     	|
# |  [Callback]ModelSummary.on_train_epoch_end                                                                                                                                                                 	|  1.2538e-05     	|  1              	|  1.2538e-05     	|  1.84e-05       	|
# |  [Callback]GradientAccumulationScheduler.on_epoch_start                                                                                                                                                    	|  4.1763e-06     	|  3              	|  1.2529e-05     	|  1.8386e-05     	|
# |  [Callback]GradientAccumulationScheduler.on_validation_end                                                                                                                                                 	|  6.1635e-06     	|  2              	|  1.2327e-05     	|  1.809e-05      	|
# |  [Callback]ModelSummary.on_train_end                                                                                                                                                                       	|  1.1647e-05     	|  1              	|  1.1647e-05     	|  1.7092e-05     	|
# |  [Callback]ModelSummary.on_validation_epoch_end                                                                                                                                                            	|  5.7885e-06     	|  2              	|  1.1577e-05     	|  1.6989e-05     	|
# |  [Callback]GradientAccumulationScheduler.on_validation_start                                                                                                                                               	|  5.604e-06      	|  2              	|  1.1208e-05     	|  1.6448e-05     	|
# |  [Callback]TQDMProgressBar.on_pretrain_routine_start                                                                                                                                                       	|  1.092e-05      	|  1              	|  1.092e-05      	|  1.6025e-05     	|
# |  [Callback]TQDMProgressBar.on_validation_epoch_start                                                                                                                                                       	|  5.232e-06      	|  2              	|  1.0464e-05     	|  1.5356e-05     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_validation_start                	|  4.912e-06      	|  2              	|  9.824e-06      	|  1.4417e-05     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_epoch_end                       	|  3.2703e-06     	|  3              	|  9.811e-06      	|  1.4398e-05     	|
# |  [Callback]ModelSummary.on_epoch_end                                                                                                                                                                       	|  3.2347e-06     	|  3              	|  9.704e-06      	|  1.4241e-05     	|
# |  [Callback]GradientAccumulationScheduler.on_epoch_end                                                                                                                                                      	|  3.181e-06      	|  3              	|  9.543e-06      	|  1.4004e-05     	|
# |  [Callback]GradientAccumulationScheduler.on_train_start                                                                                                                                                    	|  9.212e-06      	|  1              	|  9.212e-06      	|  1.3519e-05     	|
# |  [Callback]TQDMProgressBar.on_fit_end                                                                                                                                                                      	|  8.945e-06      	|  1              	|  8.945e-06      	|  1.3127e-05     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_validation_epoch_start          	|  4.302e-06      	|  2              	|  8.604e-06      	|  1.2626e-05     	|
# |  [Callback]ModelSummary.on_validation_epoch_start                                                                                                                                                          	|  4.1555e-06     	|  2              	|  8.311e-06      	|  1.2196e-05     	|
# |  [Callback]TQDMProgressBar.on_before_accelerator_backend_setup                                                                                                                                             	|  8.163e-06      	|  1              	|  8.163e-06      	|  1.1979e-05     	|
# |  [Callback]GradientAccumulationScheduler.on_validation_epoch_start                                                                                                                                         	|  4.045e-06      	|  2              	|  8.09e-06       	|  1.1872e-05     	|
# |  [LightningModule]TwoLayerNet.on_epoch_start                                                                                                                                                               	|  2.5033e-06     	|  3              	|  7.51e-06       	|  1.1021e-05     	|
# |  [Callback]GradientAccumulationScheduler.on_validation_epoch_end                                                                                                                                           	|  3.7105e-06     	|  2              	|  7.421e-06      	|  1.089e-05      	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_validation_epoch_end            	|  3.7005e-06     	|  2              	|  7.401e-06      	|  1.0861e-05     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_train_start                     	|  7.366e-06      	|  1              	|  7.366e-06      	|  1.081e-05      	|
# |  [LightningModule]TwoLayerNet.on_fit_start                                                                                                                                                                 	|  7.331e-06      	|  1              	|  7.331e-06      	|  1.0758e-05     	|
# |  [LightningModule]TwoLayerNet.configure_callbacks                                                                                                                                                          	|  7.294e-06      	|  1              	|  7.294e-06      	|  1.0704e-05     	|
# |  [LightningModule]TwoLayerNet.prepare_data                                                                                                                                                                 	|  7.241e-06      	|  1              	|  7.241e-06      	|  1.0626e-05     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_train_epoch_start               	|  7.208e-06      	|  1              	|  7.208e-06      	|  1.0578e-05     	|
# |  [Callback]ModelSummary.setup                                                                                                                                                                              	|  6.621e-06      	|  1              	|  6.621e-06      	|  9.7164e-06     	|
# |  [LightningModule]TwoLayerNet.on_validation_start                                                                                                                                                          	|  3.2235e-06     	|  2              	|  6.447e-06      	|  9.461e-06      	|
# |  [LightningModule]TwoLayerNet.on_save_checkpoint                                                                                                                                                           	|  6.431e-06      	|  1              	|  6.431e-06      	|  9.4375e-06     	|
# |  [Callback]ModelSummary.on_sanity_check_end                                                                                                                                                                	|  6.184e-06      	|  1              	|  6.184e-06      	|  9.0751e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_fit_start                       	|  6.085e-06      	|  1              	|  6.085e-06      	|  8.9298e-06     	|
# |  [Callback]ModelSummary.on_save_checkpoint                                                                                                                                                                 	|  5.915e-06      	|  1              	|  5.915e-06      	|  8.6803e-06     	|
# |  [Strategy]SingleDeviceStrategy.on_validation_start                                                                                                                                                        	|  2.867e-06      	|  2              	|  5.734e-06      	|  8.4147e-06     	|
# |  [LightningModule]TwoLayerNet.on_validation_end                                                                                                                                                            	|  2.7565e-06     	|  2              	|  5.513e-06      	|  8.0904e-06     	|
# |  [Callback]GradientAccumulationScheduler.on_sanity_check_start                                                                                                                                             	|  5.443e-06      	|  1              	|  5.443e-06      	|  7.9876e-06     	|
# |  [Callback]TQDMProgressBar.on_pretrain_routine_end                                                                                                                                                         	|  5.362e-06      	|  1              	|  5.362e-06      	|  7.8688e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_sanity_check_start              	|  5.357e-06      	|  1              	|  5.357e-06      	|  7.8614e-06     	|
# |  [LightningModule]TwoLayerNet.on_epoch_end                                                                                                                                                                 	|  1.7393e-06     	|  3              	|  5.218e-06      	|  7.6575e-06     	|
# |  [LightningModule]TwoLayerNet.on_train_dataloader                                                                                                                                                          	|  5.162e-06      	|  1              	|  5.162e-06      	|  7.5753e-06     	|
# |  [Callback]GradientAccumulationScheduler.on_save_checkpoint                                                                                                                                                	|  5.08e-06       	|  1              	|  5.08e-06       	|  7.4549e-06     	|
# |  [Callback]ModelSummary.on_pretrain_routine_start                                                                                                                                                          	|  5.032e-06      	|  1              	|  5.032e-06      	|  7.3845e-06     	|
# |  [Callback]GradientAccumulationScheduler.on_train_epoch_end                                                                                                                                                	|  5.014e-06      	|  1              	|  5.014e-06      	|  7.3581e-06     	|
# |  [Callback]TQDMProgressBar.on_fit_start                                                                                                                                                                    	|  4.981e-06      	|  1              	|  4.981e-06      	|  7.3097e-06     	|
# |  [LightningModule]TwoLayerNet.on_validation_epoch_start                                                                                                                                                    	|  2.4425e-06     	|  2              	|  4.885e-06      	|  7.1688e-06     	|
# |  [Strategy]SingleDeviceStrategy.on_validation_end                                                                                                                                                          	|  2.3995e-06     	|  2              	|  4.799e-06      	|  7.0426e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_pretrain_routine_start          	|  4.724e-06      	|  1              	|  4.724e-06      	|  6.9325e-06     	|
# |  [Callback]GradientAccumulationScheduler.on_sanity_check_end                                                                                                                                               	|  4.702e-06      	|  1              	|  4.702e-06      	|  6.9002e-06     	|
# |  [Callback]ModelSummary.on_configure_sharded_model                                                                                                                                                         	|  4.677e-06      	|  1              	|  4.677e-06      	|  6.8635e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_save_checkpoint                 	|  4.67e-06       	|  1              	|  4.67e-06       	|  6.8533e-06     	|
# |  [Callback]GradientAccumulationScheduler.on_configure_sharded_model                                                                                                                                        	|  4.574e-06      	|  1              	|  4.574e-06      	|  6.7124e-06     	|
# |  [Callback]TQDMProgressBar.teardown                                                                                                                                                                        	|  4.564e-06      	|  1              	|  4.564e-06      	|  6.6977e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_sanity_check_end                	|  4.5e-06        	|  1              	|  4.5e-06        	|  6.6038e-06     	|
# |  [Callback]GradientAccumulationScheduler.setup                                                                                                                                                             	|  4.469e-06      	|  1              	|  4.469e-06      	|  6.5583e-06     	|
# |  [Callback]GradientAccumulationScheduler.on_pretrain_routine_start                                                                                                                                         	|  4.417e-06      	|  1              	|  4.417e-06      	|  6.482e-06      	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_pretrain_routine_end            	|  4.14e-06       	|  1              	|  4.14e-06       	|  6.0755e-06     	|
# |  [Callback]ModelSummary.on_pretrain_routine_end                                                                                                                                                            	|  4.124e-06      	|  1              	|  4.124e-06      	|  6.052e-06      	|
# |  [Callback]GradientAccumulationScheduler.on_pretrain_routine_end                                                                                                                                           	|  4.022e-06      	|  1              	|  4.022e-06      	|  5.9023e-06     	|
# |  [LightningModule]TwoLayerNet.on_train_epoch_start                                                                                                                                                         	|  3.785e-06      	|  1              	|  3.785e-06      	|  5.5545e-06     	|
# |  [LightningModule]TwoLayerNet.setup                                                                                                                                                                        	|  3.767e-06      	|  1              	|  3.767e-06      	|  5.5281e-06     	|
# |  [LightningModule]TwoLayerNet.on_train_epoch_end                                                                                                                                                           	|  3.609e-06      	|  1              	|  3.609e-06      	|  5.2962e-06     	|
# |  [LightningModule]TwoLayerNet.on_val_dataloader                                                                                                                                                            	|  3.597e-06      	|  1              	|  3.597e-06      	|  5.2786e-06     	|
# |  [LightningModule]TwoLayerNet.configure_sharded_model                                                                                                                                                      	|  3.568e-06      	|  1              	|  3.568e-06      	|  5.2361e-06     	|
# |  [Callback]GradientAccumulationScheduler.on_train_end                                                                                                                                                      	|  3.45e-06       	|  1              	|  3.45e-06       	|  5.0629e-06     	|
# |  [Callback]ModelSummary.on_fit_end                                                                                                                                                                         	|  3.359e-06      	|  1              	|  3.359e-06      	|  4.9294e-06     	|
# |  [LightningModule]TwoLayerNet.on_train_start                                                                                                                                                               	|  3.227e-06      	|  1              	|  3.227e-06      	|  4.7356e-06     	|
# |  [Callback]ModelSummary.on_before_accelerator_backend_setup                                                                                                                                                	|  3.166e-06      	|  1              	|  3.166e-06      	|  4.6461e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_configure_sharded_model         	|  3.127e-06      	|  1              	|  3.127e-06      	|  4.5889e-06     	|
# |  [Callback]ModelSummary.teardown                                                                                                                                                                           	|  3.066e-06      	|  1              	|  3.066e-06      	|  4.4994e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_fit_end                         	|  2.979e-06      	|  1              	|  2.979e-06      	|  4.3717e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': None}.on_before_accelerator_backend_setup	|  2.937e-06      	|  1              	|  2.937e-06      	|  4.3101e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_train_end                       	|  2.918e-06      	|  1              	|  2.918e-06      	|  4.2822e-06     	|
# |  [Callback]GradientAccumulationScheduler.on_fit_end                                                                                                                                                        	|  2.872e-06      	|  1              	|  2.872e-06      	|  4.2147e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.teardown                           	|  2.775e-06      	|  1              	|  2.775e-06      	|  4.0723e-06     	|
# |  [Callback]GradientAccumulationScheduler.on_before_accelerator_backend_setup                                                                                                                               	|  2.748e-06      	|  1              	|  2.748e-06      	|  4.0327e-06     	|
# |  [LightningModule]TwoLayerNet.on_pretrain_routine_start                                                                                                                                                    	|  2.741e-06      	|  1              	|  2.741e-06      	|  4.0224e-06     	|
# |  [Callback]GradientAccumulationScheduler.teardown                                                                                                                                                          	|  2.654e-06      	|  1              	|  2.654e-06      	|  3.8948e-06     	|
# |  [Strategy]SingleDeviceStrategy.on_train_start                                                                                                                                                             	|  2.641e-06      	|  1              	|  2.641e-06      	|  3.8757e-06     	|
# |  [Strategy]SingleDeviceStrategy.on_train_end                                                                                                                                                               	|  2.517e-06      	|  1              	|  2.517e-06      	|  3.6937e-06     	|
# |  [LightningModule]TwoLayerNet.on_fit_end                                                                                                                                                                   	|  2.51e-06       	|  1              	|  2.51e-06       	|  3.6834e-06     	|
# |  [LightningModule]TwoLayerNet.on_train_end                                                                                                                                                                 	|  2.385e-06      	|  1              	|  2.385e-06      	|  3.5e-06        	|
# |  [LightningModule]TwoLayerNet.on_pretrain_routine_end                                                                                                                                                      	|  1.384e-06      	|  1              	|  1.384e-06      	|  2.031e-06      	|
# |  [LightningModule]TwoLayerNet.teardown                                                                                                                                                                     	|  1.159e-06      	|  1              	|  1.159e-06      	|  1.7008e-06     	|
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# We can see an overview of the time taken for different steps.
# This  enables us to detect bottlenecks in the model more easily. A bottleneck can be, for example, long times in dataloading. It becomes very important later, especially, when you start to implement custom layers or loss functions.

# %% [markdown]
# ### Some more debugging Options
#
# * [`fast_dev_run`](https://pytorch-lightning.readthedocs.io/en/latest/trainer.html#fast-dev-run): Runs of batch of each train, validation and test pass (if validation and test datalaoders are passed as arguments).This is a fast way to check if everything works (dataloading, validation metric, model saving/ loading) without having to wait for a full epoch.
#
# * [`track_grad_norm`](https://pytorch-lightning.readthedocs.io/en/latest/trainer.html#track-grad-norm): Logs the  norm of the gradients (set to `1` for the $L1$ norm or `2` for the $L2$ norm) for each layer. You can check whether the network is actually doing something. If the gradients are too small or too high, you won't have a good training (due to vanishing/ exploding gradients).
#
#
# ### Other Features
#
# Finally, we want to mention some other useful options in the Trainer class:
#
# * [`resume_from_checkpoint`](https://pytorch-lightning.readthedocs.io/en/latest/trainer.html#resume-from-checkpoint): Start the training from a checkpoint saved earlier. Argument is the path to the saved model file.
# * [`Callbacks`](https://pytorch-lightning.readthedocs.io/en/latest/callbacks.html#callback): Callbacks are extremely useful system during training that automate non essential code such as  storing model checkpoints , saving weights values among others.
#
# Let's have the look at the [`EarlyStopping`](https://pytorch-lightning.readthedocs.io/en/latest/early_stopping.html#early-stopping-based-on-metric-using-the-earlystopping-callback)  callback.
#
# It interrupts the training if the `monitor` metric variable does not  improve for `patience` number of epochs.
#
# Below is a code example on how to apply it!
#
# ```python
# from pytorch_lightning.callbacks.early_stopping import EarlyStopping
#
# early_stop_callback = EarlyStopping(
#    monitor='val_accuracy',
#    patience=3,
#    verbose=False,
#    mode='max'
# )
#
# trainer = Trainer(max_epochs=10,callbacks=[early_stop_callback])
# ```
#
# Your journey with pytorch lightning will force you to check out a bunch of callbacks to return the desired functions without having to write the respective code yourself. Or you hack it in, do as you wish :).

# %% [markdown]
# ## References
#
# 1. PyTorch Lightining [`Source Code`](https://github.com/PyTorchLightning/pytorch-lightning) with a nice introduction
# 2. PyTorch Lightining [`Documentation`](https://pytorch-lightning.readthedocs.io/en/latest/#)  Explore it! The features are very well explained.
